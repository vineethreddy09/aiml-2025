# %% [markdown]
# <a href="https://colab.research.google.com/github/vineethreddy09/aiml-2025/blob/main/LAB_10_AIML.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install ucimlrepo

# %%
import pandas as pd
from ucimlrepo import fetch_ucirepo

#fetch dataset
power_con = fetch_ucirepo(id=235)

# Access the features and targets data
X = power_con.data.features
Y = power_con.data.targets

# Create a pandas DataFrame from the data
df = pd.DataFrame(X)  # Use X for features, you can also include Y if needed

# If you want to include the targets in the DataFrame:
df['target'] = Y  # Assuming 'target' is a suitable column name

# Now you can work with the DataFrame 'df'
print(df.head())
# Out:
# /usr/local/lib/python3.10/dist-packages/ucimlrepo/fetch.py:97: DtypeWarning: Columns (2,3,4,5,6,7) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(data_url)
#          Date      Time Global_active_power Global_reactive_power  Voltage  \
# 0  16/12/2006  17:24:00               4.216                 0.418  234.840
# 1  16/12/2006  17:25:00               5.360                 0.436  233.630
# 2  16/12/2006  17:26:00               5.374                 0.498  233.290
# 3  16/12/2006  17:27:00               5.388                 0.502  233.740
# 4  16/12/2006  17:28:00               3.666                 0.528  235.680
#
#   Global_intensity Sub_metering_1 Sub_metering_2  Sub_metering_3 target
# 0           18.400          0.000          1.000            17.0   None
# 1           23.000          0.000          1.000            16.0   None
# 2           23.000          0.000          2.000            17.0   None
# ...

# %%
df=pd.read_csv("/content/household_power_consumption.txt")

# %%
type(power_con)
power_con.keys()
# Out:
# dict_keys(['data', 'metadata', 'variables'])

# %%
power_con.data.features.columns#Gives us the info about the columns
print("Top 5 power consumption results:")
power_con.data.features.head().sort_values(by='Voltage')
# Out:
# Top 5 power consumption results:
#          Date      Time Global_active_power Global_reactive_power  Voltage  \
# 2  16/12/2006  17:26:00               5.374                 0.498  233.290
# 1  16/12/2006  17:25:00               5.360                 0.436  233.630
# 3  16/12/2006  17:27:00               5.388                 0.502  233.740
# 0  16/12/2006  17:24:00               4.216                 0.418  234.840
# 4  16/12/2006  17:28:00               3.666                 0.528  235.680
#
#   Global_intensity Sub_metering_1 Sub_metering_2  Sub_metering_3
# 2           23.000          0.000          2.000            17.0
# 1           23.000          0.000          1.000            16.0
# 3           23.000          0.000          1.000            17.0
# 0           18.400          0.000          1.000            17.0
# 4           15.800          0.000          1.000            17.0

# %%
power_con.data.features.head()
# Out:
#          Date      Time Global_active_power Global_reactive_power  Voltage  \
# 0  16/12/2006  17:24:00               4.216                 0.418  234.840
# 1  16/12/2006  17:25:00               5.360                 0.436  233.630
# 2  16/12/2006  17:26:00               5.374                 0.498  233.290
# 3  16/12/2006  17:27:00               5.388                 0.502  233.740
# 4  16/12/2006  17:28:00               3.666                 0.528  235.680
#
#   Global_intensity Sub_metering_1 Sub_metering_2  Sub_metering_3
# 0           18.400          0.000          1.000            17.0
# 1           23.000          0.000          1.000            16.0
# 2           23.000          0.000          2.000            17.0
# 3           23.000          0.000          1.000            17.0
# 4           15.800          0.000          1.000            17.0

# %%
power_con.data.features.head().sort_values(by="Voltage")
# Out:
#          Date      Time Global_active_power Global_reactive_power  Voltage  \
# 2  16/12/2006  17:26:00               5.374                 0.498  233.290
# 1  16/12/2006  17:25:00               5.360                 0.436  233.630
# 3  16/12/2006  17:27:00               5.388                 0.502  233.740
# 0  16/12/2006  17:24:00               4.216                 0.418  234.840
# 4  16/12/2006  17:28:00               3.666                 0.528  235.680
#
#   Global_intensity Sub_metering_1 Sub_metering_2  Sub_metering_3
# 2           23.000          0.000          2.000            17.0
# 1           23.000          0.000          1.000            16.0
# 3           23.000          0.000          1.000            17.0
# 0           18.400          0.000          1.000            17.0
# 4           15.800          0.000          1.000            17.0

# %%
power_con.data.features.head().sort_values(by="Date")
# Out:
#          Date      Time Global_active_power Global_reactive_power  Voltage  \
# 0  16/12/2006  17:24:00               4.216                 0.418  234.840
# 1  16/12/2006  17:25:00               5.360                 0.436  233.630
# 2  16/12/2006  17:26:00               5.374                 0.498  233.290
# 3  16/12/2006  17:27:00               5.388                 0.502  233.740
# 4  16/12/2006  17:28:00               3.666                 0.528  235.680
#
#   Global_intensity Sub_metering_1 Sub_metering_2  Sub_metering_3
# 0           18.400          0.000          1.000            17.0
# 1           23.000          0.000          1.000            16.0
# 2           23.000          0.000          2.000            17.0
# 3           23.000          0.000          1.000            17.0
# 4           15.800          0.000          1.000            17.0

# %%
print("Top 10 power Consumption Time and Dates:")
power_con.data.features.head(10).sort_values(by="Time")
# Out:
# Top 10 power Consumption Time and Dates:
#          Date      Time Global_active_power Global_reactive_power  Voltage  \
# 0  16/12/2006  17:24:00               4.216                 0.418  234.840
# 1  16/12/2006  17:25:00               5.360                 0.436  233.630
# 2  16/12/2006  17:26:00               5.374                 0.498  233.290
# 3  16/12/2006  17:27:00               5.388                 0.502  233.740
# 4  16/12/2006  17:28:00               3.666                 0.528  235.680
# 5  16/12/2006  17:29:00               3.520                 0.522  235.020
# 6  16/12/2006  17:30:00               3.702                 0.520  235.090
# 7  16/12/2006  17:31:00               3.700                 0.520  235.220
# 8  16/12/2006  17:32:00               3.668                 0.510  233.990
# 9  16/12/2006  17:33:00               3.662                 0.510  233.860
#
#   Global_intensity Sub_metering_1 Sub_metering_2  Sub_metering_3
# ...

# %%
power_con.data.features.head().sort_values(by="Date").values
# Out:
# array([['16/12/2006', '17:24:00', '4.216', '0.418', '234.840', '18.400',
#         '0.000', '1.000', 17.0],
#        ['16/12/2006', '17:25:00', '5.360', '0.436', '233.630', '23.000',
#         '0.000', '1.000', 16.0],
#        ['16/12/2006', '17:26:00', '5.374', '0.498', '233.290', '23.000',
#         '0.000', '2.000', 17.0],
#        ['16/12/2006', '17:27:00', '5.388', '0.502', '233.740', '23.000',
#         '0.000', '1.000', 17.0],
#        ['16/12/2006', '17:28:00', '3.666', '0.528', '235.680', '15.800',
#         '0.000', '1.000', 17.0]], dtype=object)

# %%
power_con_df=DataFrame(power_con.data.features)
type(power_con_df)
# Out:
# pandas.core.frame.DataFrame

# %%
power_con_df.hist(figsize=(10,10))
# Out:
# array([[<Axes: title={'center': 'Sub_metering_3'}>]], dtype=object)

# %%
import seaborn as sns

# %%
sns.countplot(x=power_con_df.columns[4],hue=power_con_df.columns[5],data=power_con_df,palette='rainbow')
# Out:
# <Axes: xlabel='Voltage', ylabel='count'>

# %%
import sklearn.preprocessing as preprocessing
from sklearn.model_selection import train_test_split
y = X['Appliances']
X = X.drop(columns=['Appliances'])
X.shape, y.shape  # Now this line should execute without error
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3804         try:
# -> 3805             return self._engine.get_loc(casted_key)
#    3806         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Appliances'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-42-0513968f3ff8> in <cell line: 3>()
#       1 import sklearn.preprocessing as preprocessing
# ...

# %%
power_con.df.columns.head()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-38-920391545aff> in <cell line: 1>()
# ----> 1 power_con.df.columns.head()
#
# AttributeError: 'NoneType' object has no attribute 'columns'

# %%
import sklearn.preprocessing as preprocessing
from sklearn.model_selection import train_test_split
X=power_con_df.drop('Time',axis=1)
y=power_con_df['Time']
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2,random_state=101)

# %%
power_con_df.shape,X_train.shape,y_train.shape,y_test.shape

# %%
import sklearn.cluster as cluster

# %%
power_con_df.head()
power_con_df_float=power_con_df.astype(float)
